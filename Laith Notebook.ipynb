# %%
import pandas as pd
import numpy as np
import metrica.Metrica_IO as mio 
import matplotlib.pyplot as plt
import metrica.Metrica_Velocities as mvel
import metrica.Metrica_Viz as mviz
import metrica.Metrica_EPV as mepv
DATADIR = './data/'
game_id = 1

tracking_home = mio.tracking_data(DATADIR,game_id,'Home')

tracking_home
# Out:
# Reading team: home
#         Period  Time [s]  Home_11_x  Home_11_y  Home_1_x  Home_1_y  Home_2_x  \
# Frame
# 1            1      0.04    0.00082    0.48238   0.32648   0.65322   0.33701
# 2            1      0.08    0.00096    0.48238   0.32648   0.65322   0.33701
# 3            1      0.12    0.00114    0.48238   0.32648   0.65322   0.33701
# 4            1      0.16    0.00121    0.48238   0.32622   0.65317   0.33687
# 5            1      0.20    0.00129    0.48238   0.32597   0.65269   0.33664
# ...        ...       ...        ...        ...       ...       ...       ...
# 145002       2   5800.08    0.90614    0.45355       NaN       NaN   0.34157
# 145003       2   5800.12    0.90550    0.45355       NaN       NaN   0.34127
# 145004       2   5800.16    0.90492    0.45355       NaN       NaN   0.34089
# 145005       2   5800.20    0.90456    0.45356       NaN       NaN   0.34056
# 145006       2   5800.24    0.90456    0.45356       NaN       NaN   0.33996
#
# ...

# %%
#tracking_home_one = tracking_home[0:50]
#for x in range(10):
#   tracking_home_one.plot( x=f'Home_{x}_x',y=f'Home_{x}_y', xlim=(0,1),ylim=(0,1))   
player1_df = tracking_home[["Period","Time [s]","Home_1_x","Home_1_y","ball_x","ball_y"]]

#fig, axes = plt.subplots(nrows=4, ncols=4)
#tracking_home_one.plot( x='ball_x',y=f'ball_y', xlim=(0,1),ylim=(0,1))


tracking_home = mvel.calc_player_velocities(tracking_home,smoothing=False)

tracking_home 




# tracking_home_one.plot(ax=axes[0,1], x='Home_1_x',y=f'Home_1_y', xlim=(0,1),ylim=(0,1))   

# tracking_home_one.plot( ax=axes[0,2],x='Home_2_x',y=f'Home_2_y', xlim=(0,1),ylim=(0,1))   
# tracking_home_one.plot( ax=axes[0,3],x='Home_3_x',y=f'Home_3_y', xlim=(0,1),ylim=(0,1))   
# tracking_home_one.plot( ax=axes[1,0],x='Home_4_x',y=f'Home_4_y', xlim=(0,1),ylim=(0,1))   
# tracking_home_one.plot( ax=axes[1,1],x='Home_5_x',y=f'Home_5_y', xlim=(0,1),ylim=(0,1))   

# tracking_home_one.plot( ax=axes[1,2],x='Home_6_x',y=f'Home_6_y', xlim=(0,1),ylim=(0,1))   
# tracking_home_one.plot( ax=axes[1,3],x='Home_7_x',y=f'Home_7_y', xlim=(0,1),ylim=(0,1))   
# tracking_home_one.plot( ax=axes[2,0],x='Home_8_x',y=f'Home_8_y', xlim=(0,1),ylim=(0,1))   
# tracking_home_one.plot( ax=axes[2,1],x='Home_9_x',y=f'Home_9_y', xlim=(0,1),ylim=(0,1))   

# tracking_home_one.plot( ax=axes[2,2],x='Home_10_x',y=f'Home_10_y', xlim=(0,1),ylim=(0,1))   
# tracking_home_one.plot( ax=axes[2,3],x='Home_11_x',y=f'Home_11_y', xlim=(0,1),ylim=(0,1))   
# tracking_home_one.plot( ax=axes[3,0],x='Home_12_x',y=f'Home_12_y', xlim=(0,1),ylim=(0,1))   
# tracking_home_one.plot( ax=axes[3,1],x='Home_14_x',y=f'Home_14_y', xlim=(0,1),ylim=(0,1))
# Out:
#         Period  Time [s]  Home_11_x  Home_11_y  Home_1_x  Home_1_y  Home_2_x  \
# Frame
# 1            1      0.04    0.00082    0.48238   0.32648   0.65322   0.33701
# 2            1      0.08    0.00096    0.48238   0.32648   0.65322   0.33701
# 3            1      0.12    0.00114    0.48238   0.32648   0.65322   0.33701
# 4            1      0.16    0.00121    0.48238   0.32622   0.65317   0.33687
# 5            1      0.20    0.00129    0.48238   0.32597   0.65269   0.33664
# ...        ...       ...        ...        ...       ...       ...       ...
# 145002       2   5800.08    0.90614    0.45355       NaN       NaN   0.34157
# 145003       2   5800.12    0.90550    0.45355       NaN       NaN   0.34127
# 145004       2   5800.16    0.90492    0.45355       NaN       NaN   0.34089
# 145005       2   5800.20    0.90456    0.45356       NaN       NaN   0.34056
# 145006       2   5800.24    0.90456    0.45356       NaN       NaN   0.33996
#
# ...

# %%
# Get the player ids
player_ids = np.unique( [ c[:-2] for c in tracking_home.columns if c[:4] in ['Home','Away'] ] )


# index of first frame in second half
tracking_home.plot(x='Time [s]',y='Home_9_speed', xlim=(0,1),ylim=(0,.2))  

# estimate velocities for players in team
#for player in player_ids: # cycle through players individually
    #print (player)
    #tracking_home.plot(x='Time [s]',y=player+'_speed', xlim=(0,1),ylim=(0,1))
# Out:
# <Axes: xlabel='Time [s]'>
