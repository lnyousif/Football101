# %%
import pandas as pd
import numpy as np
import metrica.Metrica_IO as mio 
import matplotlib.pyplot as plt
import metrica.Metrica_Velocities as mvel
DATADIR = './data/'
game_id = 1

tracking_home = mio.tracking_data(DATADIR,game_id,'Home')

tracking_home
# Out:
# Reading team: home
#         Period  Time [s]  Home_11_x  Home_11_y  Home_1_x  Home_1_y  Home_2_x  \
# Frame
# 1            1      0.04    0.00082    0.48238   0.32648   0.65322   0.33701
# 2            1      0.08    0.00096    0.48238   0.32648   0.65322   0.33701
# 3            1      0.12    0.00114    0.48238   0.32648   0.65322   0.33701
# 4            1      0.16    0.00121    0.48238   0.32622   0.65317   0.33687
# 5            1      0.20    0.00129    0.48238   0.32597   0.65269   0.33664
# ...        ...       ...        ...        ...       ...       ...       ...
# 145002       2   5800.08    0.90614    0.45355       NaN       NaN   0.34157
# 145003       2   5800.12    0.90550    0.45355       NaN       NaN   0.34127
# 145004       2   5800.16    0.90492    0.45355       NaN       NaN   0.34089
# 145005       2   5800.20    0.90456    0.45356       NaN       NaN   0.34056
# 145006       2   5800.24    0.90456    0.45356       NaN       NaN   0.33996
#
# ...

# %%
#tracking_home_one = tracking_home[0:50]
#for x in range(10):
#   tracking_home_one.plot( x=f'Home_{x}_x',y=f'Home_{x}_y', xlim=(0,1),ylim=(0,1))   
player1_df = tracking_home[["Period","Time [s]","Home_1_x","Home_1_y","ball_x","ball_y"]]

#fig, axes = plt.subplots(nrows=4, ncols=4)
#tracking_home_one.plot( x='ball_x',y=f'ball_y', xlim=(0,1),ylim=(0,1))
tracking_home_speed =tracking_home

tracking_home_speed = mvel.calc_player_velocities(tracking_home_speed,smoothing=False)

tracking_home_speed



# tracking_home_one.plot(ax=axes[0,1], x='Home_1_x',y=f'Home_1_y', xlim=(0,1),ylim=(0,1))
# Out:
#         Period  Time [s]  Home_11_x  Home_11_y  Home_1_x  Home_1_y  Home_2_x  \
# Frame
# 1            1      0.04    0.00082    0.48238   0.32648   0.65322   0.33701
# 2            1      0.08    0.00096    0.48238   0.32648   0.65322   0.33701
# 3            1      0.12    0.00114    0.48238   0.32648   0.65322   0.33701
# 4            1      0.16    0.00121    0.48238   0.32622   0.65317   0.33687
# 5            1      0.20    0.00129    0.48238   0.32597   0.65269   0.33664
# ...        ...       ...        ...        ...       ...       ...       ...
# 145002       2   5800.08    0.90614    0.45355       NaN       NaN   0.34157
# 145003       2   5800.12    0.90550    0.45355       NaN       NaN   0.34127
# 145004       2   5800.16    0.90492    0.45355       NaN       NaN   0.34089
# 145005       2   5800.20    0.90456    0.45356       NaN       NaN   0.34056
# 145006       2   5800.24    0.90456    0.45356       NaN       NaN   0.33996
#
# ...

# %%
# Get the player ids
player_ids = np.unique( [ c[:-2] for c in tracking_home.columns if c[:4] in ['Home','Away'] ] )


# index of first frame in second half
#tracking_home_speed.plot(x='Time [s]',y=['Home_5_x','Home_5_y'], xlim=(0,200))  

tracking_home1 = tracking_home_speed[:1000]

plt.plot(tracking_home1['Time [s]'],tracking_home1['Home_1_speed'], marker='o', linestyle='', markersize=1, color='g', label='Scatter Plot')
plt.plot(tracking_home1['Time [s]'],tracking_home1['Home_2_speed'], marker='o', linestyle='', markersize=1, color='g', label='Scatter Plot')
plt.plot(tracking_home1['Time [s]'],tracking_home1['Home_3_speed'], marker='o', linestyle='', markersize=1, color='b', label='Scatter Plot')
plt.plot(tracking_home1['Time [s]'],tracking_home1['Home_4_speed'], marker='o', linestyle='', markersize=1, color='r', label='Scatter Plot')


plt.ylim(0, .2)
plt.show()

# estimate velocities for players in team
#for player in player_ids: # cycle through players individually
    #print (player)
    #tracking_home.plot(x='Time [s]',y=player+'_speed', xlim=(0,1),ylim=(0,1))

# %%
tracking_home2 = tracking_home_speed[5000:6000]

plt.plot(tracking_home2['Time [s]'],tracking_home2['Home_1_speed'], marker='o', linestyle='', markersize=1, color='g', label='Scatter Plot')
plt.plot(tracking_home2['Time [s]'],tracking_home2['Home_2_speed'], marker='o', linestyle='', markersize=1, color='g', label='Scatter Plot')
plt.plot(tracking_home2['Time [s]'],tracking_home2['Home_3_speed'], marker='o', linestyle='', markersize=1, color='b', label='Scatter Plot')
plt.plot(tracking_home2['Time [s]'],tracking_home2['Home_4_speed'], marker='o', linestyle='', markersize=1, color='r', label='Scatter Plot')


plt.ylim(0, .2)
plt.show()

# %%
df = tracking_home.melt(id_vars=['Period','Time [s]'])

df
# Out:
#          Period  Time [s]   variable    value
# 0             1      0.04  Home_11_x  0.00082
# 1             1      0.08  Home_11_x  0.00096
# 2             1      0.12  Home_11_x  0.00114
# 3             1      0.16  Home_11_x  0.00121
# 4             1      0.20  Home_11_x  0.00129
# ...         ...       ...        ...      ...
# 4350175       2   5800.08     ball_y      NaN
# 4350176       2   5800.12     ball_y      NaN
# 4350177       2   5800.16     ball_y      NaN
# 4350178       2   5800.20     ball_y      NaN
# 4350179       2   5800.24     ball_y      NaN
#
# [4350180 rows x 4 columns]

# %%
#df.info()
df['variable'] = df['variable'].astype(str)
df.info()

df_11 = df.loc[df['variable'].isin(['Home_11_x','Home_11_y'])]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4350180 entries, 0 to 4350179
# Data columns (total 4 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   Period    int64
#  1   Time [s]  float64
#  2   variable  object
#  3   value     float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 132.8+ MB

# %%
plt.plot(tracking_home1['Time [s]'],tracking_home1['Home_1_speed'], marker='o', linestyle='', markersize=1, color='g', label='Scatter Plot')

plt.plot(tracking_home2['Time [s]'],tracking_home2['Home_1_speed'], marker='o', linestyle='', markersize=1, color='g', label='Scatter Plot')
plt.title("Player 1")
plt.show()


plt.plot(tracking_home1['Time [s]'],tracking_home1['Home_2_speed'], marker='o', linestyle='', markersize=1, color='r', label='Scatter Plot')

plt.plot(tracking_home2['Time [s]'],tracking_home2['Home_2_speed'], marker='o', linestyle='', markersize=1, color='r', label='Scatter Plot')
plt.title("Player 2")

plt.show()

plt.plot(tracking_home1['Time [s]'],tracking_home1['Home_3_speed'], marker='o', linestyle='', markersize=1, color='y', label='Scatter Plot')

plt.plot(tracking_home2['Time [s]'],tracking_home2['Home_3_speed'], marker='o', linestyle='', markersize=1, color='y', label='Scatter Plot')
plt.title("Player 3")

plt.show()

# %%
plt.plot(tracking_home1['Time [s]'],tracking_home1['Home_1_distance_ball'], marker='o', linestyle='', markersize=1, color='y', label='Scatter Plot')

plt.plot(tracking_home2['Time [s]'],tracking_home2['Home_1_distance_ball'], marker='o', linestyle='', markersize=1, color='y', label='Scatter Plot')
plt.title("Player 1 Distance from ball")
plt.show()

plt.plot(tracking_home1['Time [s]'],tracking_home1['Home_2_distance_ball'], marker='o', linestyle='', markersize=1, color='y', label='Scatter Plot')

plt.plot(tracking_home2['Time [s]'],tracking_home2['Home_2_distance_ball'], marker='o', linestyle='', markersize=1, color='y', label='Scatter Plot')
plt.title("Player 2 Distance from ball")

plt.show()
plt.plot(tracking_home1['Time [s]'],tracking_home1['Home_3_distance_ball'], marker='o', linestyle='', markersize=1, color='y', label='Scatter Plot')

plt.plot(tracking_home2['Time [s]'],tracking_home2['Home_3_distance_ball'], marker='o', linestyle='', markersize=1, color='y', label='Scatter Plot')
plt.title("Player 3 Distance from ball")

plt.show()

plt.plot(tracking_home1['Time [s]'],tracking_home1['Home_4_distance_ball'], marker='o', linestyle='', markersize=1, color='y', label='Scatter Plot')

plt.plot(tracking_home2['Time [s]'],tracking_home2['Home_4_distance_ball'], marker='o', linestyle='', markersize=1, color='y', label='Scatter Plot')
plt.title("Player 4 Distance from ball")

plt.show()
plt.plot(tracking_home1['Time [s]'],tracking_home1['Home_5_distance_ball'], marker='o', linestyle='', markersize=1, color='y', label='Scatter Plot')

plt.plot(tracking_home2['Time [s]'],tracking_home2['Home_5_distance_ball'], marker='o', linestyle='', markersize=1, color='y', label='Scatter Plot')
plt.title("Player 5 Distance from ball")

plt.show()
plt.plot(tracking_home1['Time [s]'],tracking_home1['Home_6_distance_ball'], marker='o', linestyle='', markersize=1, color='y', label='Scatter Plot')

plt.plot(tracking_home2['Time [s]'],tracking_home2['Home_6_distance_ball'], marker='o', linestyle='', markersize=1, color='y', label='Scatter Plot')
plt.title("Player 6 Distance from ball")

plt.show()
plt.plot(tracking_home1['Time [s]'],tracking_home1['Home_7_distance_ball'], marker='o', linestyle='', markersize=1, color='y', label='Scatter Plot')

plt.plot(tracking_home2['Time [s]'],tracking_home2['Home_7_distance_ball'], marker='o', linestyle='', markersize=1, color='y', label='Scatter Plot')
plt.title("Player 7 Distance from ball")

plt.show()
plt.plot(tracking_home1['Time [s]'],tracking_home1['Home_8_distance_ball'], marker='o', linestyle='', markersize=1, color='y', label='Scatter Plot')

plt.plot(tracking_home2['Time [s]'],tracking_home2['Home_8_distance_ball'], marker='o', linestyle='', markersize=1, color='y', label='Scatter Plot')
plt.title("Player 8 Distance from ball")

plt.show()

plt.plot(tracking_home1['Time [s]'],tracking_home1['Home_9_distance_ball'], marker='o', linestyle='', markersize=1, color='y', label='Scatter Plot')

plt.plot(tracking_home2['Time [s]'],tracking_home2['Home_9_distance_ball'], marker='o', linestyle='', markersize=1, color='y', label='Scatter Plot')
plt.title("Player 9 Distance from ball")

plt.show()

plt.plot(tracking_home1['Time [s]'],tracking_home1['Home_10_distance_ball'], marker='o', linestyle='', markersize=1, color='y', label='Scatter Plot')

plt.plot(tracking_home2['Time [s]'],tracking_home2['Home_10_distance_ball'], marker='o', linestyle='', markersize=1, color='y', label='Scatter Plot')
plt.title("Player 10 Distance from ball")

plt.show()

plt.plot(tracking_home1['Time [s]'],tracking_home1['Home_11_distance_ball'], marker='o', linestyle='', markersize=1, color='y', label='Scatter Plot')

plt.plot(tracking_home2['Time [s]'],tracking_home2['Home_11_distance_ball'], marker='o', linestyle='', markersize=1, color='y', label='Scatter Plot')
plt.title("Player 11 Distance from ball")

plt.show()

# %%
plt.plot(tracking_home1['Time [s]'],tracking_home1['Home_1_vx'], marker='x', linestyle='', markersize=1, color='y', label='Scatter Plot')


plt.plot(tracking_home1['Time [s]'],tracking_home1['Home_1_vy'], marker='o', linestyle='', markersize=1, color='r', label='Scatter Plot')

plt.title("Player 1 xv yv")
plt.show()


plt.plot(tracking_home2['Time [s]'],tracking_home2['Home_1_vx'], marker='x', linestyle='', markersize=1, color='y', label='Scatter Plot')

plt.plot(tracking_home2['Time [s]'],tracking_home2['Home_1_vy'], marker='o', linestyle='', markersize=1, color='r', label='Scatter Plot')

plt.title("Player 1 xv yv")
plt.show()

# %%
tracking_home_adv = tracking_home.loc[tracking_home['ball_x']-0.5>0]
tracking_home_dis = tracking_home.loc[tracking_home['ball_x']-0.5<0]

plt.plot(tracking_home_adv['Time [s]'],tracking_home_adv['ball_x']-0.5, marker='o', linestyle='', markersize=1, color='b', label='Scatter Plot')
plt.plot(tracking_home_dis['Time [s]'],tracking_home_dis['ball_x']-0.5, marker='o', linestyle='', markersize=1, color='r', label='Scatter Plot')
plt.title("Ball position through the match between the 2 sides")
plt.show()
